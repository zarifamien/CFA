# %% [markdown]
# ## Load Required Libraries

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load Data

# %%
def load_dataset(currency_pair):
  DATA_FOLDER = '../phase_01_data_collection/data'
  file_path = os.path.join(DATA_FOLDER, f"{currency_pair}.csv")
  df = pd.read_csv(file_path)
  df["Timestamp"] = pd.to_datetime(df["Timestamp"], unit="s")
  df.set_index("Timestamp", inplace=True)
  return df

# %%
currencies = ['btcusd', 'adausd', 'dogeusd', 'ethusd', 'solusd', 'xrpusd']
df = load_dataset(currencies[0])
df.head()
# Out:
#                       Open   High    Low  Close     Volume
# Timestamp
# 2024-10-02 03:30:00  61702  61866  61695  61736   4.648565
# 2024-10-02 04:00:00  61735  61740  61485  61614  12.122374
# 2024-10-02 04:30:00  61574  61577  61438  61467   1.528846
# 2024-10-02 05:00:00  61472  61844  61395  61423  95.785281
# 2024-10-02 05:30:00  61433  61482  61352  61473  26.779352

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# summarized statistics of the data
df.describe()
# Out:
#                 Open           High            Low          Close       Volume
# count    5000.000000    5000.000000    5000.000000    5000.000000  5000.000000
# mean    85269.084400   85476.167200   85052.679400   85274.667200    48.070588
# std     14734.602713   14780.239706   14675.848773   14730.194987    69.061739
# min     58998.000000   59427.000000   58867.000000   59007.000000     0.000000
# 25%     68417.750000   68508.750000   68351.750000   68419.000000     9.162782
# 50%     93335.500000   93593.000000   93073.500000   93319.000000    23.527313
# 75%     97307.000000   97548.750000   97085.500000   97315.000000    57.336035
# max    108293.000000  108364.000000  107240.000000  108276.000000   914.810298

# %%
# to visualize the distribution of the 'Close' prices
plt.figure(figsize=(10, 6))
sns.histplot(df['Close'], kde=True)
plt.title("Distribution of Close Prices")
plt.xlabel('Price (USD)')
plt.ylabel('Frequency')
plt.show()

# %%
# correlation Heatmap
correlation = df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
